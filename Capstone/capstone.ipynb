# %%
# !pip install statsmodels
# Out:
# Fatal Python error: config_get_locale_encoding: failed to get the locale encoding: nl_langinfo(CODESET) failed
# Python runtime state: preinitialized

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('cc_institution_details.csv', encoding='latin-1')
df1
# Out:
#       unitid                                chronname             city  \
# 0     100654                   Alabama A&M University           Normal
# 1     100663      University of Alabama at Birmingham       Birmingham
# 2     100690                       Amridge University       Montgomery
# 3     100706      University of Alabama at Huntsville       Huntsville
# 4     100724                 Alabama State University       Montgomery
# ...      ...                                      ...              ...
# 3793  461528                Grace College of Divinity     Fayetteville
# 3794  462354  John Paul the Great Catholic University        Escondido
# 3795  466921  Chamberlain College of Nursing-Missouri        St. Louis
# 3796  474881              Minneapolis Media Institute            Edina
# 3797  475291            Brown College-Brooklyn Center  Brooklyn Center
#
#                state   level                 control  \
# 0            Alabama  4-year                  Public
# ...

# %%
def to_snake_case(string):
    return string.lower().replace(" ", "_")

# Apply the function to each value in the column
df1['control'] = df1['control'].apply(to_snake_case)

def to_snake_case(string):
    return string.lower().replace("-", "_")

# Apply the function to each value in the column
df1['control'] = df1['control'].apply(to_snake_case)

# %%
df1
# Out:
#       unitid                                chronname             city  \
# 0     100654                   Alabama A&M University           Normal
# 1     100663      University of Alabama at Birmingham       Birmingham
# 2     100690                       Amridge University       Montgomery
# 3     100706      University of Alabama at Huntsville       Huntsville
# 4     100724                 Alabama State University       Montgomery
# ...      ...                                      ...              ...
# 3793  461528                Grace College of Divinity     Fayetteville
# 3794  462354  John Paul the Great Catholic University        Escondido
# 3795  466921  Chamberlain College of Nursing-Missouri        St. Louis
# 3796  474881              Minneapolis Media Institute            Edina
# 3797  475291            Brown College-Brooklyn Center  Brooklyn Center
#
#                state   level                 control  \
# 0            Alabama  4-year                  public
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3798 entries, 0 to 3797
# Data columns (total 62 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   unitid                                3798 non-null   int64
#  1   chronname                             3798 non-null   object
#  2   city                                  3798 non-null   object
#  3   state                                 3798 non-null   object
#  4   level                                 3798 non-null   object
#  5   control                               3798 non-null   object
#  6   basic                                 3798 non-null   object
#  7   hbcu                                  94 non-null     object
#  8   flagship                              50 non-null     object
#  9   long_x                                3798 non-null   float64
#  10  lat_y                                 3798 non-null   float64
# ...

# %%
df2 = pd.read_csv('cc_institution_grads.csv')
df2
# Out:
#          unitid  year gender race    cohort  grad_cohort  grad_100  grad_150  \
# 0        100760  2011      B    X    2y all        446.0      73.0     105.0
# 1        100760  2011      M    X    2y all        185.0       NaN      40.0
# 2        100760  2011      F    X    2y all        261.0       NaN      65.0
# 3        100760  2011      B    W    2y all        348.0       NaN      86.0
# 4        100760  2011      M    W    2y all        162.0       NaN      35.0
# ...         ...   ...    ...  ...       ...          ...       ...       ...
# 1302097  168591  2002      F   Ai  4y other          NaN       NaN       NaN
# 1302098  168740  2002      F   Ai  4y other          0.0       NaN       0.0
# 1302099  169716  2002      F   Ai  4y other          NaN       NaN       NaN
# 1302100  170082  2002      F   Ai  4y other          NaN       NaN       NaN
# 1302101  170091  2002      F   Ai  4y other          0.0       NaN       0.0
#
#          grad_100_rate  grad_150_rate
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1302102 entries, 0 to 1302101
# Data columns (total 10 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   unitid         1302102 non-null  int64
#  1   year           1302102 non-null  int64
#  2   gender         1302102 non-null  object
#  3   race           1302102 non-null  object
#  4   cohort         1302102 non-null  object
#  5   grad_cohort    889380 non-null   float64
#  6   grad_100       410069 non-null   float64
#  7   grad_150       889380 non-null   float64
#  8   grad_100_rate  332061 non-null   float64
#  9   grad_150_rate  694869 non-null   float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 99.3+ MB

# %%
df2.describe()
# Out:
#              unitid          year    grad_cohort       grad_100  \
# count  1.302102e+06  1.302102e+06  889380.000000  410069.000000
# mean   2.179693e+05  2.007527e+03     110.220918      52.155776
# std    9.770375e+04  3.459778e+00     349.705681     178.195728
# min    1.006540e+05  2.002000e+03       0.000000       0.000000
# 25%    1.540220e+05  2.005000e+03       1.000000       0.000000
# 50%    1.953040e+05  2.008000e+03       8.000000       2.000000
# 75%    2.291790e+05  2.011000e+03      75.000000      25.000000
# max    4.752910e+05  2.013000e+03   73066.000000    5243.000000
#
#             grad_150  grad_100_rate  grad_150_rate
# count  889380.000000  332061.000000  694869.000000
# mean       50.555137      30.209467      39.259078
# std       194.141071      28.159988      30.172468
# min         0.000000       0.000000       0.000000
# 25%         0.000000       4.300000      14.000000
# 50%         2.000000      24.700000      35.700000
# ...

# %%
selected_columns_df1 = df1[['unitid', 'chronname', 'level', 'control']]
selected_columns_df2 = df2[['unitid', 'gender', 'grad_100', 'grad_150', 'year']]
new_df = pd.merge(selected_columns_df1, df2, on='unitid', how = 'inner')
new_df
# Out:
#          unitid                      chronname   level             control  \
# 0        100654         Alabama A&M University  4-year              public
# 1        100654         Alabama A&M University  4-year              public
# 2        100654         Alabama A&M University  4-year              public
# 3        100654         Alabama A&M University  4-year              public
# 4        100654         Alabama A&M University  4-year              public
# ...         ...                            ...     ...                 ...
# 1259491  475291  Brown College-Brooklyn Center  4-year  private_for_profit
# 1259492  475291  Brown College-Brooklyn Center  4-year  private_for_profit
# 1259493  475291  Brown College-Brooklyn Center  4-year  private_for_profit
# 1259494  475291  Brown College-Brooklyn Center  4-year  private_for_profit
# 1259495  475291  Brown College-Brooklyn Center  4-year  private_for_profit
#
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259496 entries, 0 to 1259495
# Data columns (total 13 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   unitid         1259496 non-null  int64
#  1   chronname      1259496 non-null  object
#  2   level          1259496 non-null  object
#  3   control        1259496 non-null  object
#  4   year           1259496 non-null  int64
#  5   gender         1259496 non-null  object
#  6   race           1259496 non-null  object
#  7   cohort         1259496 non-null  object
#  8   grad_cohort    862344 non-null   float64
#  9   grad_100       402228 non-null   float64
#  10  grad_150       862344 non-null   float64
#  11  grad_100_rate  326367 non-null   float64
#  12  grad_150_rate  675206 non-null   float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 124.9+ MB

# %%
new_df.describe()
# Out:
#              unitid          year    grad_cohort       grad_100  \
# count  1.259496e+06  1.259496e+06  862344.000000  402228.000000
# mean   2.162115e+05  2.007579e+03     112.019078      52.643550
# std    9.588527e+04  3.473890e+00     354.254207     179.319213
# min    1.006540e+05  2.002000e+03       0.000000       0.000000
# 25%    1.542085e+05  2.005000e+03       1.000000       0.000000
# 50%    1.951640e+05  2.008000e+03       8.000000       2.000000
# 75%    2.285010e+05  2.011000e+03      76.000000      26.000000
# max    4.752910e+05  2.013000e+03   73066.000000    5243.000000
#
#             grad_150  grad_100_rate  grad_150_rate
# count  862344.000000  326367.000000  675206.000000
# mean       51.442840      30.173136      39.284791
# std       196.661403      28.085988      30.111775
# min         0.000000       0.000000       0.000000
# 25%         0.000000       4.400000      14.200000
# 50%         2.000000      24.700000      35.900000
# ...

# %%
filtered_new_df_all = new_df[(new_df['gender'] == 'B') & (new_df['race'] == 'X')]

# %%
filtered_new_df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 69972 entries, 0 to 1259478
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   unitid         69972 non-null  int64
#  1   chronname      69972 non-null  object
#  2   level          69972 non-null  object
#  3   control        69972 non-null  object
#  4   year           69972 non-null  int64
#  5   gender         69972 non-null  object
#  6   race           69972 non-null  object
#  7   cohort         69972 non-null  object
#  8   grad_cohort    47908 non-null  float64
#  9   grad_100       29282 non-null  float64
#  10  grad_150       47908 non-null  float64
#  11  grad_100_rate  29282 non-null  float64
#  12  grad_150_rate  47908 non-null  float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 7.5+ MB

# %%
filtered_new_df_all.head()
# Out:
#     unitid               chronname   level control  year gender race  \
# 0   100654  Alabama A&M University  4-year  public  2011      B    X
# 18  100654  Alabama A&M University  4-year  public  2012      B    X
# 36  100654  Alabama A&M University  4-year  public  2013      B    X
# 54  100654  Alabama A&M University  4-year  public  2011      B    X
# 72  100654  Alabama A&M University  4-year  public  2012      B    X
#
#       cohort  grad_cohort  grad_100  grad_150  grad_100_rate  grad_150_rate
# 0   4y other          NaN       NaN       NaN            NaN            NaN
# 18  4y other          NaN       NaN       NaN            NaN            NaN
# 36  4y other          NaN       NaN       NaN            NaN            NaN
# 54   4y bach       1088.0     116.0     345.0           10.7           31.7
# 72   4y bach       1133.0     110.0     365.0            9.7           32.2

# %%
filtered_new_df_all1 = filtered_new_df_all[filtered_new_df_all['cohort'] == '4y bach']

# %%
filtered_new_df_all1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26052 entries, 54 to 1259478
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   unitid         26052 non-null  int64
#  1   chronname      26052 non-null  object
#  2   level          26052 non-null  object
#  3   control        26052 non-null  object
#  4   year           26052 non-null  int64
#  5   gender         26052 non-null  object
#  6   race           26052 non-null  object
#  7   cohort         26052 non-null  object
#  8   grad_cohort    21938 non-null  float64
#  9   grad_100       21938 non-null  float64
#  10  grad_150       21938 non-null  float64
#  11  grad_100_rate  21938 non-null  float64
#  12  grad_150_rate  21938 non-null  float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 2.8+ MB

# %%
cleaned_filtered_new_df_all1 = filtered_new_df_all1.dropna(subset=['grad_100', 'grad_150'])

# %%
cleaned_filtered_new_df_all1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21938 entries, 54 to 1259478
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   unitid         21938 non-null  int64
#  1   chronname      21938 non-null  object
#  2   level          21938 non-null  object
#  3   control        21938 non-null  object
#  4   year           21938 non-null  int64
#  5   gender         21938 non-null  object
#  6   race           21938 non-null  object
#  7   cohort         21938 non-null  object
#  8   grad_cohort    21938 non-null  float64
#  9   grad_100       21938 non-null  float64
#  10  grad_150       21938 non-null  float64
#  11  grad_100_rate  21938 non-null  float64
#  12  grad_150_rate  21938 non-null  float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 2.3+ MB

# %%
cleaned_filtered_new_df_all1.describe()
# Out:
#               unitid          year   grad_cohort      grad_100      grad_150  \
# count   21938.000000  21938.000000  21938.000000  21938.000000  21938.000000
# mean   197229.595770   2007.742593    658.470872    241.115052    380.055292
# std     73054.975545      3.441879    972.698459    446.926308    667.712849
# min    100654.000000   2002.000000      1.000000      0.000000      0.000000
# 25%    153278.000000   2005.000000    123.000000     23.000000     44.000000
# 50%    189228.000000   2008.000000    316.000000     89.000000    150.000000
# 75%    217493.000000   2011.000000    725.000000    259.000000    405.000000
# max    475291.000000   2013.000000  18003.000000   5243.000000   6859.000000
#
#        grad_100_rate  grad_150_rate
# count   21938.000000   21938.000000
# mean       33.053323      48.837884
# std        23.234019      22.031335
# min         0.000000       0.000000
# 25%        14.900000      34.700000
# 50%        29.500000      49.000000
# ...

# %%
sns.displot(data = cleaned_filtered_new_df_all1, x = "year", kde = True, palette="Greens", edgecolor="black", bins=25, line_kws={"linewidth":2})
# Out:
# /var/folders/zj/15qg5mcs2svc83k3_z0qxg7h0000gn/T/ipykernel_77058/4081673925.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(data = cleaned_filtered_new_df_all1, x = "year", kde = True, palette="Greens", edgecolor="black", bins=25, line_kws={"linewidth":2})
# /Users/sudhakrishnamoorthy/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
filtered_new_df = new_df[(new_df['gender'] != 'B') & (new_df['level'] != '2-year') & (new_df['cohort'] != '4y other')]

# %%
filtered_new_df.head()
# Out:
#     unitid               chronname   level control  year gender race   cohort  \
# 55  100654  Alabama A&M University  4-year  public  2011      M    X  4y bach
# 56  100654  Alabama A&M University  4-year  public  2011      F    X  4y bach
# 58  100654  Alabama A&M University  4-year  public  2011      M    W  4y bach
# 59  100654  Alabama A&M University  4-year  public  2011      F    W  4y bach
# 61  100654  Alabama A&M University  4-year  public  2011      M    B  4y bach
#
#     grad_cohort  grad_100  grad_150  grad_100_rate  grad_150_rate
# 55        516.0      27.0     130.0            5.2           25.2
# 56        572.0      89.0     215.0           15.6           37.6
# 58          7.0       1.0       1.0           14.3           14.3
# 59          6.0       0.0       2.0            0.0           33.3
# 61        500.0      25.0     127.0            5.0           25.4

# %%
filtered_new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 319644 entries, 55 to 1259495
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   unitid         319644 non-null  int64
#  1   chronname      319644 non-null  object
#  2   level          319644 non-null  object
#  3   control        319644 non-null  object
#  4   year           319644 non-null  int64
#  5   gender         319644 non-null  object
#  6   race           319644 non-null  object
#  7   cohort         319644 non-null  object
#  8   grad_cohort    269328 non-null  float64
#  9   grad_100       263244 non-null  float64
#  10  grad_150       269328 non-null  float64
#  11  grad_100_rate  205856 non-null  float64
#  12  grad_150_rate  209979 non-null  float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 34.1+ MB

# %%
filtered_new_df.describe()
# Out:
#               unitid           year    grad_cohort      grad_100  \
# count  319644.000000  319644.000000  269328.000000  263244.00000
# mean   212146.565154    2007.580583     104.960773      38.81603
# std     91386.209791       3.474389     284.233734     129.07434
# min    100654.000000    2002.000000       0.000000       0.00000
# 25%    154101.000000    2005.000000       1.000000       0.00000
# 50%    193399.000000    2008.000000       7.000000       1.00000
# 75%    225247.000000    2011.000000      74.000000      18.00000
# max    475291.000000    2013.000000   11683.000000    2783.00000
#
#             grad_150  grad_100_rate  grad_150_rate
# count  269328.000000  205856.000000  209979.000000
# mean       60.523098      30.333476      46.299938
# std       190.002447      28.716131      29.688110
# min         0.000000       0.000000       0.000000
# 25%         0.000000       2.400000      25.000000
# 50%         3.000000      24.700000      48.000000
# ...

# %%
filtered_new_df['chronname'].value_counts()
# Out:
# chronname
# Alabama A&M University                                             144
# Juniata College                                                    144
# Gettysburg College                                                 144
# Gwynedd-Mercy College                                              144
# Haverford College                                                  144
#                                                                   ...
# The Art Institute of California-Argosy University Inland Empire     36
# National American University-Zona Rosa                              36
# Westwood College-Annandale                                          36
# Rasmussen College-Illinois                                          36
# Brown College-Brooklyn Center                                       36
# Name: count, Length: 2338, dtype: int64

# %%
filtered_new_df['year'].value_counts()
# Out:
# year
# 2011    28068
# 2012    28068
# 2013    28068
# 2010    26160
# 2009    26160
# 2008    26160
# 2007    26160
# 2006    26160
# 2005    26160
# 2004    26160
# 2003    26160
# 2002    26160
# Name: count, dtype: int64

# %%
missing_values = filtered_new_df.isnull()
missing_count = missing_values.sum()
missing_info = pd.DataFrame({'Missing Count': missing_count})
print(missing_info)
# Out:
#                Missing Count
# unitid                     0
# chronname                  0
# level                      0
# control                    0
# year                       0
# gender                     0
# race                       0
# cohort                     0
# grad_cohort            50316
# grad_100               56400
# grad_150               50316
# grad_100_rate         113788
# grad_150_rate         109665

# %%
cleaned_filtered_new_df= filtered_new_df.dropna(subset=['grad_100', 'grad_150', 'grad_100_rate', 'grad_150_rate'])

# %%
cleaned_filtered_new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 205856 entries, 55 to 1259494
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   unitid         205856 non-null  int64
#  1   chronname      205856 non-null  object
#  2   level          205856 non-null  object
#  3   control        205856 non-null  object
#  4   year           205856 non-null  int64
#  5   gender         205856 non-null  object
#  6   race           205856 non-null  object
#  7   cohort         205856 non-null  object
#  8   grad_cohort    205856 non-null  float64
#  9   grad_100       205856 non-null  float64
#  10  grad_150       205856 non-null  float64
#  11  grad_100_rate  205856 non-null  float64
#  12  grad_150_rate  205856 non-null  float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 22.0+ MB

# %%
cleaned_filtered_new_df.head()
# Out:
#     unitid               chronname   level control  year gender race   cohort  \
# 55  100654  Alabama A&M University  4-year  public  2011      M    X  4y bach
# 56  100654  Alabama A&M University  4-year  public  2011      F    X  4y bach
# 58  100654  Alabama A&M University  4-year  public  2011      M    W  4y bach
# 59  100654  Alabama A&M University  4-year  public  2011      F    W  4y bach
# 61  100654  Alabama A&M University  4-year  public  2011      M    B  4y bach
#
#     grad_cohort  grad_100  grad_150  grad_100_rate  grad_150_rate
# 55        516.0      27.0     130.0            5.2           25.2
# 56        572.0      89.0     215.0           15.6           37.6
# 58          7.0       1.0       1.0           14.3           14.3
# 59          6.0       0.0       2.0            0.0           33.3
# 61        500.0      25.0     127.0            5.0           25.4

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='race', data=cleaned_filtered_new_df)
plt.title('Bar Plot of Race Column')
plt.xlabel('Race')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='gender', data=cleaned_filtered_new_df)
plt.title('Bar Plot of Race Column')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='race', y='grad_100_rate', data=cleaned_filtered_new_df)
plt.title('Box Plot of 4 Year Graduation Rate by Race')
plt.xlabel('Race')
plt.ylabel('4 Year Graduation Rate')
plt.xticks(rotation=45) 
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='race', y='grad_150_rate', data=cleaned_filtered_new_df)
plt.title('Box Plot of 6 Year Graduation rate by Race')
plt.xlabel('Race')
plt.ylabel('6 Year Graduation Rate')
plt.xticks(rotation=45)  
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='gender', y='grad_100_rate', data=cleaned_filtered_new_df)
plt.title('Box Plot of 4 Year Graduation Rate by Gender')
plt.xlabel('Gender')
plt.ylabel('4 Year Graduation Rate')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='gender', y='grad_150_rate', data=cleaned_filtered_new_df)
plt.title('Box Plot of 6 Year Graduation Rate by Race')
plt.xlabel('Gender')
plt.ylabel('6 Year Graduation Rate')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame containing 'gender' and 'grad_100_rate' columns

# Plot histogram
plt.figure(figsize=(10, 6))
sns.histplot(data=cleaned_filtered_new_df, x='grad_100_rate', hue='gender', kde=True)
plt.title('Histogram of 4 Year Graduation Rate by Gender')
plt.xlabel('4 Year Graduation Rate')
plt.ylabel('Frequency')
plt.legend(title='Gender')
plt.show()
# Out:
# /Users/sudhakrishnamoorthy/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/sudhakrishnamoorthy/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/sudhakrishnamoorthy/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
sns.displot(data = cleaned_filtered_new_df, x = "year", kde = True, palette="Greens", edgecolor="black", bins=25, line_kws={"linewidth":2})
# Out:
# /var/folders/zj/15qg5mcs2svc83k3_z0qxg7h0000gn/T/ipykernel_77058/737062071.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(data = cleaned_filtered_new_df, x = "year", kde = True, palette="Greens", edgecolor="black", bins=25, line_kws={"linewidth":2})
# /Users/sudhakrishnamoorthy/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
cleaned_filtered_new_df['year'] = pd.to_datetime(cleaned_filtered_new_df['year'], format='%Y')
yearly_totals = cleaned_filtered_new_df.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_100', 'grad_cohort']].sum()
yearly_totals['grad_rate'] = yearly_totals['grad_100'] / yearly_totals['grad_cohort']
# Out:
# /var/folders/zj/15qg5mcs2svc83k3_z0qxg7h0000gn/T/ipykernel_77058/4134574612.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_filtered_new_df['year'] = pd.to_datetime(cleaned_filtered_new_df['year'], format='%Y')

# %%
plt.figure(figsize=(10, 6))
plt.plot(yearly_totals.index, yearly_totals['grad_rate'], marker='o', linestyle='-')
plt.title('Time Series of 4 Year Graduation Rate')
plt.xlabel('Year')
plt.ylabel('4 Year Graduation Rate')
plt.grid(True)
plt.xticks(yearly_totals.index)  # Set x-ticks to be the years
plt.tight_layout()
plt.show()

# %%
cleaned_filtered_new_df['year'] = pd.to_datetime(cleaned_filtered_new_df['year'], format='%Y')
yearly_totals = cleaned_filtered_new_df.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_150', 'grad_cohort']].sum()
yearly_totals['grad_rate'] = yearly_totals['grad_150'] / yearly_totals['grad_cohort']
plt.figure(figsize=(10, 6))
plt.plot(yearly_totals.index, yearly_totals['grad_rate'], marker='o', linestyle='-')
plt.title('Time Series of 6 Year Graduation Rate')
plt.xlabel('Year')
plt.ylabel('6 Year Graduation Rate')
plt.grid(True)
plt.xticks(yearly_totals.index)  # Set x-ticks to be the years
plt.tight_layout()
plt.show()
# Out:
# /var/folders/zj/15qg5mcs2svc83k3_z0qxg7h0000gn/T/ipykernel_77058/1731259053.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_filtered_new_df['year'] = pd.to_datetime(cleaned_filtered_new_df['year'], format='%Y')

# %%
cleaned_filtered_new_df['year'] = pd.to_datetime(cleaned_filtered_new_df['year'], format='%Y')
male_data = cleaned_filtered_new_df[cleaned_filtered_new_df['gender'] == 'M']
female_data = cleaned_filtered_new_df[cleaned_filtered_new_df['gender'] == 'F']
male_yearly_totals = male_data.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_100', 'grad_cohort']].sum()
female_yearly_totals = female_data.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_100', 'grad_cohort']].sum()
male_yearly_totals['grad_rate'] = male_yearly_totals['grad_100'] / male_yearly_totals['grad_cohort']
female_yearly_totals['grad_rate'] = female_yearly_totals['grad_100'] / female_yearly_totals['grad_cohort']
plt.figure(figsize=(10, 6))
plt.plot(male_yearly_totals.index, male_yearly_totals['grad_rate'], marker='o', linestyle='-', label='Male')
plt.plot(female_yearly_totals.index, female_yearly_totals['grad_rate'], marker='o', linestyle='-', label='Female')
plt.title('Comparative Time Series of  4 Year Graduation Rates by Gender')
plt.xlabel('Year')
plt.ylabel('4 Year Graduation Rate')
plt.legend()
plt.grid(True)
plt.xticks(male_yearly_totals.index)  # Set x-ticks to be the years from male data
plt.tight_layout()
plt.show()
# Out:
# /var/folders/zj/15qg5mcs2svc83k3_z0qxg7h0000gn/T/ipykernel_77058/3909147190.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_filtered_new_df['year'] = pd.to_datetime(cleaned_filtered_new_df['year'], format='%Y')

# %%
cleaned_filtered_new_df['year'] = pd.to_datetime(cleaned_filtered_new_df['year'], format='%Y')
male_data = cleaned_filtered_new_df[cleaned_filtered_new_df['gender'] == 'M']
female_data = cleaned_filtered_new_df[cleaned_filtered_new_df['gender'] == 'F']
male_yearly_totals = male_data.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_150', 'grad_cohort']].sum()
female_yearly_totals = female_data.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_150', 'grad_cohort']].sum()
male_yearly_totals['grad_rate'] = male_yearly_totals['grad_150'] / male_yearly_totals['grad_cohort']
female_yearly_totals['grad_rate'] = female_yearly_totals['grad_150'] / female_yearly_totals['grad_cohort']
plt.figure(figsize=(10, 6))
plt.plot(male_yearly_totals.index, male_yearly_totals['grad_rate'], marker='o', linestyle='-', label='Male')
plt.plot(female_yearly_totals.index, female_yearly_totals['grad_rate'], marker='o', linestyle='-', label='Female')
plt.title('Comparative Time Series of  6 Year Graduation Rates by Gender')
plt.xlabel('Year')
plt.ylabel('6 Year Graduation Rate')
plt.legend()
plt.grid(True)
plt.xticks(male_yearly_totals.index)  # Set x-ticks to be the years from male data
plt.tight_layout()
plt.show()
# Out:
# /var/folders/zj/15qg5mcs2svc83k3_z0qxg7h0000gn/T/ipykernel_77058/84720274.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_filtered_new_df['year'] = pd.to_datetime(cleaned_filtered_new_df['year'], format='%Y')

# %%
cleaned_filtered_new_df['year'] = pd.to_datetime(cleaned_filtered_new_df['year'], format='%Y')
white_data = cleaned_filtered_new_df[cleaned_filtered_new_df['race'] == 'W']
black_data = cleaned_filtered_new_df[cleaned_filtered_new_df['race'] == 'B']
hispanic_data = cleaned_filtered_new_df[cleaned_filtered_new_df['race'] == 'H']
american_indian_data = cleaned_filtered_new_df[cleaned_filtered_new_df['race'] == 'Ai']
asian_data = cleaned_filtered_new_df[cleaned_filtered_new_df['race'] == 'A']
white_yearly_totals = white_data.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_100', 'grad_cohort']].sum()
black_yearly_totals = black_data.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_100', 'grad_cohort']].sum()
hispanic_yearly_totals = hispanic_data.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_100', 'grad_cohort']].sum()
american_indian_yearly_totals = american_indian_data.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_100', 'grad_cohort']].sum()
asian_yearly_totals = asian_data.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_100', 'grad_cohort']].sum()
white_yearly_totals['grad_rate'] = white_yearly_totals['grad_100'] / white_yearly_totals['grad_cohort']
black_yearly_totals['grad_rate'] = black_yearly_totals['grad_100'] / black_yearly_totals['grad_cohort']
hispanic_yearly_totals['grad_rate'] = hispanic_yearly_totals['grad_100'] / hispanic_yearly_totals['grad_cohort']
american_indian_yearly_totals['grad_rate'] = american_indian_yearly_totals['grad_100'] / american_indian_yearly_totals['grad_cohort']
asian_yearly_totals['grad_rate'] = asian_yearly_totals['grad_100'] / asian_yearly_totals['grad_cohort']
plt.figure(figsize=(10, 6))
plt.plot(white_yearly_totals.index, white_yearly_totals['grad_rate'], marker='o', linestyle='-', label='White')
plt.plot(black_yearly_totals.index, black_yearly_totals['grad_rate'], marker='o', linestyle='-', label='Black')
plt.plot(hispanic_yearly_totals.index, hispanic_yearly_totals['grad_rate'], marker='o', linestyle='-', label='Hispanic')
plt.plot(american_indian_yearly_totals.index, american_indian_yearly_totals['grad_rate'], marker='o', linestyle='-', label='American Indian')
plt.plot(asian_yearly_totals.index, asian_yearly_totals['grad_rate'], marker='o', linestyle='-', label='Asian')
plt.title('Comparative Time Series of  4 Year Graduation Rates by Race')
plt.xlabel('Year')
plt.ylabel('4 Year Graduation Rate')
plt.legend()
plt.grid(True)
plt.xticks(white_yearly_totals.index)  # Set x-ticks to be the years from male data
plt.tight_layout()
plt.show()
# Out:
# /var/folders/zj/15qg5mcs2svc83k3_z0qxg7h0000gn/T/ipykernel_77058/1178830639.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_filtered_new_df['year'] = pd.to_datetime(cleaned_filtered_new_df['year'], format='%Y')

# %%
cleaned_filtered_new_df['year'] = pd.to_datetime(cleaned_filtered_new_df['year'], format='%Y')
white_data = cleaned_filtered_new_df[cleaned_filtered_new_df['race'] == 'W']
black_data = cleaned_filtered_new_df[cleaned_filtered_new_df['race'] == 'B']
hispanic_data = cleaned_filtered_new_df[cleaned_filtered_new_df['race'] == 'H']
american_indian_data = cleaned_filtered_new_df[cleaned_filtered_new_df['race'] == 'Ai']
asian_data = cleaned_filtered_new_df[cleaned_filtered_new_df['race'] == 'A']
white_yearly_totals = white_data.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_150', 'grad_cohort']].sum()
black_yearly_totals = black_data.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_150', 'grad_cohort']].sum()
hispanic_yearly_totals = hispanic_data.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_150', 'grad_cohort']].sum()
american_indian_yearly_totals = american_indian_data.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_150', 'grad_cohort']].sum()
asian_yearly_totals = asian_data.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_150', 'grad_cohort']].sum()
white_yearly_totals['grad_rate'] = white_yearly_totals['grad_150'] / white_yearly_totals['grad_cohort']
black_yearly_totals['grad_rate'] = black_yearly_totals['grad_150'] / black_yearly_totals['grad_cohort']
hispanic_yearly_totals['grad_rate'] = hispanic_yearly_totals['grad_150'] / hispanic_yearly_totals['grad_cohort']
american_indian_yearly_totals['grad_rate'] = american_indian_yearly_totals['grad_150'] / american_indian_yearly_totals['grad_cohort']
asian_yearly_totals['grad_rate'] = asian_yearly_totals['grad_150'] / asian_yearly_totals['grad_cohort']
plt.figure(figsize=(10, 6))
plt.plot(white_yearly_totals.index, white_yearly_totals['grad_rate'], marker='o', linestyle='-', label='White')
plt.plot(black_yearly_totals.index, black_yearly_totals['grad_rate'], marker='o', linestyle='-', label='Black')
plt.plot(hispanic_yearly_totals.index, hispanic_yearly_totals['grad_rate'], marker='o', linestyle='-', label='Hispanic')
plt.plot(american_indian_yearly_totals.index, american_indian_yearly_totals['grad_rate'], marker='o', linestyle='-', label='American Indian')
plt.plot(asian_yearly_totals.index, asian_yearly_totals['grad_rate'], marker='o', linestyle='-', label='Asian')
plt.title('Comparative Time Series of 6 Year Graduation Rates by Race')
plt.xlabel('Year')
plt.ylabel('6 Year Graduation Rate')
plt.legend()
plt.grid(True)
plt.xticks(white_yearly_totals.index)  # Set x-ticks to be the years from male data
plt.tight_layout()
plt.show()
# Out:
# /var/folders/zj/15qg5mcs2svc83k3_z0qxg7h0000gn/T/ipykernel_77058/4050215563.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_filtered_new_df['year'] = pd.to_datetime(cleaned_filtered_new_df['year'], format='%Y')

# %%
unique_count = cleaned_filtered_new_df['control'].nunique()

# %%
print(unique_count)
# Out:
# 3

# %%
value_counts = cleaned_filtered_new_df['control'].value_counts()
print("Value counts in 'control':\n", value_counts)
# Out:
# Value counts in 'control':
#  control
# private_not_for_profit    116106
# public                     71920
# private_for_profit         17830
# Name: count, dtype: int64

# %%
cleaned_filtered_new_df['year'] = pd.to_datetime(cleaned_filtered_new_df['year'], format='%Y')
public_data = cleaned_filtered_new_df[cleaned_filtered_new_df['control'] == 'public']
private_for_profit_data = cleaned_filtered_new_df[cleaned_filtered_new_df['control'] == 'private_for_profit']
private_non_profit_data = cleaned_filtered_new_df[cleaned_filtered_new_df['control'] == 'private_not_for_profit']
public_yearly_totals = public_data.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_100', 'grad_cohort']].sum()
private_for_profit_yearly_totals = private_for_profit_data.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_100', 'grad_cohort']].sum()
private_non_profit_yearly_totals = private_non_profit_data.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_100', 'grad_cohort']].sum()
public_yearly_totals['grad_rate'] = public_yearly_totals['grad_100'] / public_yearly_totals['grad_cohort']
private_for_profit_yearly_totals['grad_rate'] = private_for_profit_yearly_totals['grad_100'] / private_for_profit_yearly_totals['grad_cohort']
private_non_profit_yearly_totals['grad_rate'] = private_non_profit_yearly_totals['grad_100'] / private_non_profit_yearly_totals['grad_cohort']
plt.figure(figsize=(10, 6))
plt.plot(public_yearly_totals.index, public_yearly_totals['grad_rate'], marker='o', linestyle='-', label='Public')
plt.plot(private_for_profit_yearly_totals.index, private_for_profit_yearly_totals['grad_rate'], marker='o', linestyle='-', label='Private For Profit')
plt.plot(private_non_profit_yearly_totals.index, private_non_profit_yearly_totals['grad_rate'], marker='o', linestyle='-', label='Private Not For Profit')
plt.title('Comparative Time Series of 4 Year Graduation Rates by University Type')
plt.xlabel('Year')
plt.ylabel('4 Year Graduation Rate')
plt.legend()
plt.grid(True)
plt.xticks(public_yearly_totals.index)  # Set x-ticks to be the years from male data
plt.tight_layout()
plt.show()
# Out:
# /var/folders/zj/15qg5mcs2svc83k3_z0qxg7h0000gn/T/ipykernel_77058/4127483163.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_filtered_new_df['year'] = pd.to_datetime(cleaned_filtered_new_df['year'], format='%Y')

# %%
cleaned_filtered_new_df['year'] = pd.to_datetime(cleaned_filtered_new_df['year'], format='%Y')
public_data = cleaned_filtered_new_df[cleaned_filtered_new_df['control'] == 'public']
private_for_profit_data = cleaned_filtered_new_df[cleaned_filtered_new_df['control'] == 'private_for_profit']
private_non_profit_data = cleaned_filtered_new_df[cleaned_filtered_new_df['control'] == 'private_not_for_profit']
public_yearly_totals = public_data.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_150', 'grad_cohort']].sum()
private_for_profit_yearly_totals = private_for_profit_data.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_150', 'grad_cohort']].sum()
private_non_profit_yearly_totals = private_non_profit_data.groupby(cleaned_filtered_new_df['year'].dt.year)[['grad_150', 'grad_cohort']].sum()
public_yearly_totals['grad_rate'] = public_yearly_totals['grad_150'] / public_yearly_totals['grad_cohort']
private_for_profit_yearly_totals['grad_rate'] = private_for_profit_yearly_totals['grad_150'] / private_for_profit_yearly_totals['grad_cohort']
private_non_profit_yearly_totals['grad_rate'] = private_non_profit_yearly_totals['grad_150'] / private_non_profit_yearly_totals['grad_cohort']
plt.figure(figsize=(10, 6))
plt.plot(public_yearly_totals.index, public_yearly_totals['grad_rate'], marker='o', linestyle='-', label='Public')
plt.plot(private_for_profit_yearly_totals.index, private_for_profit_yearly_totals['grad_rate'], marker='o', linestyle='-', label='Private For Profit')
plt.plot(private_non_profit_yearly_totals.index, private_non_profit_yearly_totals['grad_rate'], marker='o', linestyle='-', label='Private Not For Profit')
plt.title('Comparative Time Series of 6 Year Graduation Rates by University Type')
plt.xlabel('Year')
plt.ylabel('6 Year Graduation Rate')
plt.legend()
plt.grid(True)
plt.xticks(public_yearly_totals.index)  # Set x-ticks to be the years from male data
plt.tight_layout()
plt.show()
# Out:
# /var/folders/zj/15qg5mcs2svc83k3_z0qxg7h0000gn/T/ipykernel_77058/976411194.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_filtered_new_df['year'] = pd.to_datetime(cleaned_filtered_new_df['year'], format='%Y')

# %%
pip install scipy
# Out:
# Fatal Python error: config_get_locale_encoding: failed to get the locale encoding: nl_langinfo(CODESET) failed
# Python runtime state: preinitialized
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy.stats import pearsonr, spearmanr

# %%
# calculate correlation and pvalue of 4 year grad rate and gender with spearmanr method
spearmanr(cleaned_filtered_new_df['grad_100_rate'], cleaned_filtered_new_df['gender'])
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# SignificanceResult(statistic=-0.14007356424609538, pvalue=0.0)

# %% [markdown]
# The results suggests that there is a weak but statistically significant negative correlation between the 4-year graduation rate and gender.

# %%
# calculate correlation and pvalue of 4 year grad rate and race with spearmanr method
spearmanr(cleaned_filtered_new_df['grad_100_rate'], cleaned_filtered_new_df['race'])
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# SignificanceResult(statistic=0.13209499828580248, pvalue=0.0)

# %% [markdown]
# The results suggests that there is a weak but statistically significant positive correlation between the 4-year graduation rate and race.

# %%
# calculate correlation and pvalue of 4 year grad rate and university type with spearmanr method
spearmanr(cleaned_filtered_new_df['grad_100_rate'], cleaned_filtered_new_df['control'])
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# SignificanceResult(statistic=-0.1347375289450775, pvalue=0.0)

# %% [markdown]
# The results suggests that there is a weak but statistically significant negative correlation between the 4-year graduation rate and university type.

# %%
# create pairplot of dataframe
#import pandas as pd
#cleaned_filtered_new_df = pd.read_csv("salary_numeric.csv")
#salary_df.head()
import seaborn as sns
sns.set()
sns.pairplot(cleaned_filtered_new_df)
# Out:
# /Users/sudhakrishnamoorthy/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/sudhakrishnamoorthy/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/sudhakrishnamoorthy/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# use pd.crosstab() to calculate mean salary in each industry grouped by education level
import numpy as np
crosstab= pd.crosstab(index=cleaned_filtered_new_df["gender"], columns= cleaned_filtered_new_df["race"], values=cleaned_filtered_new_df["grad_100_rate"], aggfunc=np.mean).round(0)
# Out:
# /var/folders/zj/15qg5mcs2svc83k3_z0qxg7h0000gn/T/ipykernel_77058/394176619.py:3: FutureWarning: The provided callable <function mean at 0x7f9f00391670> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   crosstab= pd.crosstab(index=cleaned_filtered_new_df["gender"], columns= cleaned_filtered_new_df["race"], values=cleaned_filtered_new_df["grad_100_rate"], aggfunc=np.mean).round(0)

# %%
# create heatmap with annotated mean 4 year graduation rate for male and female and different races
plt.figure(figsize=(12,8))
ax = sns.heatmap(crosstab, annot=True, linewidths=.5, cmap='YlGnBu', fmt='g', xticklabels=['Asian', 'American Indian', "Black", "Hispanic", "White", "All"])

plt.xlabel("Race", fontsize=14)
plt.ylabel("Gender", fontsize=14)

plt.title("4 Year Grad Rates across Genders by Race", fontsize=18);
plt.show()

# %% [markdown]
# From the heatmap we can conclude:
# 1. Females having higher 4 year graduation rates than males
# 2. Within the same gender, Asians and Whites have the highest 4 year graduation rates.

# %% [markdown]
# import numpy as np
# import pandas as pd
# import scipy
# import statsmodels.api as sm
# import matplotlib.pyplot as plt
# import seaborn as sns
# import sklearn

# %%
pip install statsmodels
# Out:
# Fatal Python error: config_get_locale_encoding: failed to get the locale encoding: nl_langinfo(CODESET) failed
# Python runtime state: preinitialized
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Fatal Python error: config_get_locale_encoding: failed to get the locale encoding: nl_langinfo(CODESET) failed
# Python runtime state: preinitialized
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import scipy
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
# set X 
x1 = cleaned_filtered_new_df["gender"]

# set Y 
y = cleaned_filtered_new_df["grad_100"]

# %%
# visualize relationship between X and Y
plt.scatter(x1,y)
plt.xlabel("Gender", fontsize = 20)
plt.ylabel("4 year Graduates", fontsize =20)
plt.show()

# %%
# Convert categorical columns to dummy variables
dummy_vars = pd.get_dummies(cleaned_filtered_new_df[['gender']], drop_first=True)

# Concatenate dummy variables with the numeric column
#X = pd.concat([cleaned_filtered_new_df['grad_150_rate'], dummy_vars], axis=1)


#X = sm.add_constant(dummy_vars)


#y = cleaned_filtered_new_df['grad_150_rate']

#model = sm.OLS(y, X).fit()


#print(model.summary())

# %%
dummy_vars.head()
# Out:
#     gender_M
# 55      True
# 56     False
# 58      True
# 59     False
# 61      True

# %%
column_sum = dummy_vars['gender_M'].sum()

print(column_sum)
# Out:
# 101400

# %%
cleaned_filtered_new_df.loc[:, 'gender'] = cleaned_filtered_new_df['gender'].astype(str)

# %%
cleaned_filtered_new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 205856 entries, 55 to 1259494
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   unitid         205856 non-null  int64
#  1   chronname      205856 non-null  object
#  2   level          205856 non-null  object
#  3   control        205856 non-null  object
#  4   year           205856 non-null  datetime64[ns]
#  5   gender         205856 non-null  object
#  6   race           205856 non-null  object
#  7   cohort         205856 non-null  object
#  8   grad_cohort    205856 non-null  float64
#  9   grad_100       205856 non-null  float64
#  10  grad_150       205856 non-null  float64
#  11  grad_100_rate  205856 non-null  float64
#  12  grad_150_rate  205856 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(6)
# memory usage: 30.1+ MB

# %%
cleaned_filtered_new_df.head(10)
# Out:
#     unitid               chronname   level control       year gender race  \
# 55  100654  Alabama A&M University  4-year  public 2011-01-01      M    X
# 56  100654  Alabama A&M University  4-year  public 2011-01-01      F    X
# 58  100654  Alabama A&M University  4-year  public 2011-01-01      M    W
# 59  100654  Alabama A&M University  4-year  public 2011-01-01      F    W
# 61  100654  Alabama A&M University  4-year  public 2011-01-01      M    B
# 62  100654  Alabama A&M University  4-year  public 2011-01-01      F    B
# 64  100654  Alabama A&M University  4-year  public 2011-01-01      M    H
# 65  100654  Alabama A&M University  4-year  public 2011-01-01      F    H
# 67  100654  Alabama A&M University  4-year  public 2011-01-01      M   Ai
# 68  100654  Alabama A&M University  4-year  public 2011-01-01      F   Ai
#
#      cohort  grad_cohort  grad_100  grad_150  grad_100_rate  grad_150_rate
# 55  4y bach        516.0      27.0     130.0            5.2           25.2
# ...

# %%
cleaned_filtered_new_df_copy = cleaned_filtered_new_df.copy()

# %%
cleaned_filtered_new_df_copy .drop(cleaned_filtered_new_df_copy[cleaned_filtered_new_df_copy['race'] == 'X'].index, inplace=True)

# %%
cleaned_filtered_new_df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 163332 entries, 58 to 1259494
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   unitid         163332 non-null  int64
#  1   chronname      163332 non-null  object
#  2   level          163332 non-null  object
#  3   control        163332 non-null  object
#  4   year           163332 non-null  datetime64[ns]
#  5   gender         163332 non-null  object
#  6   race           163332 non-null  object
#  7   cohort         163332 non-null  object
#  8   grad_cohort    163332 non-null  float64
#  9   grad_100       163332 non-null  float64
#  10  grad_150       163332 non-null  float64
#  11  grad_100_rate  163332 non-null  float64
#  12  grad_150_rate  163332 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(6)
# memory usage: 17.4+ MB

# %%
dummy_vars = pd.get_dummies(cleaned_filtered_new_df_copy[['gender']])
dummy_vars.head()
# Out:
#     gender_F  gender_M
# 58     False      True
# 59      True     False
# 61     False      True
# 62      True     False
# 64     False      True

# %%
column_sum = dummy_vars['gender_M'].sum()

print(column_sum)
# Out:
# 80207

# %%
dummy_vars = pd.get_dummies(cleaned_filtered_new_df_copy[['race']])

# %%
dummy_vars.head()
# Out:
#     race_A  race_Ai  race_B  race_H  race_W
# 58   False    False   False   False    True
# 59   False    False   False   False    True
# 61   False    False    True   False   False
# 62   False    False    True   False   False
# 64   False    False   False    True   False

# %%
dummy_vars = pd.get_dummies(cleaned_filtered_new_df_copy[['race']])
#dummy_vars.head()

# %%
X= dummy_vars
y=cleaned_filtered_new_df_copy['grad_100_rate']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#                             OLS Regression Results
# ...
# Dep. Variable:          grad_100_rate   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     1092.
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):               0.00
# Time:                        10:43:10   Log-Likelihood:            -7.8402e+05
# No. Observations:              163332   AIC:                         1.568e+06
# Df Residuals:                  163327   BIC:                         1.568e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ...

# %%
dummy_vars = pd.get_dummies(cleaned_filtered_new_df_copy[['race']])
X= dummy_vars
y=cleaned_filtered_new_df_copy['grad_150_rate']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#                             OLS Regression Results
# ...
# Dep. Variable:          grad_150_rate   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     1055.
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):               0.00
# Time:                        10:43:10   Log-Likelihood:            -7.9123e+05
# No. Observations:              163332   AIC:                         1.582e+06
# Df Residuals:                  163327   BIC:                         1.583e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ...

# %%
dummy_vars = pd.get_dummies(cleaned_filtered_new_df_copy[['gender']])
X= dummy_vars
y=cleaned_filtered_new_df_copy['grad_100_rate']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#                             OLS Regression Results
# ...
# Dep. Variable:          grad_100_rate   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     2915.
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):               0.00
# Time:                        10:43:10   Log-Likelihood:            -7.8473e+05
# No. Observations:              163332   AIC:                         1.569e+06
# Df Residuals:                  163330   BIC:                         1.569e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
dummy_vars = pd.get_dummies(cleaned_filtered_new_df_copy[['gender']])
X= dummy_vars
y=cleaned_filtered_new_df_copy['grad_150_rate']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#                             OLS Regression Results
# ...
# Dep. Variable:          grad_150_rate   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     1668.
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):               0.00
# Time:                        10:43:10   Log-Likelihood:            -7.9249e+05
# No. Observations:              163332   AIC:                         1.585e+06
# Df Residuals:                  163330   BIC:                         1.585e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
dummy_vars = pd.get_dummies(cleaned_filtered_new_df_copy[['control']])
X= dummy_vars
y=cleaned_filtered_new_df_copy['grad_100_rate']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#                             OLS Regression Results
# ...
# Dep. Variable:          grad_100_rate   R-squared:                       0.093
# Model:                            OLS   Adj. R-squared:                  0.093
# Method:                 Least Squares   F-statistic:                     8416.
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):               0.00
# Time:                        10:43:10   Log-Likelihood:            -7.7816e+05
# No. Observations:              163332   AIC:                         1.556e+06
# Df Residuals:                  163329   BIC:                         1.556e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %%
dummy_vars = pd.get_dummies(cleaned_filtered_new_df_copy[['control']])
X= dummy_vars
y=cleaned_filtered_new_df_copy['grad_150_rate']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#                             OLS Regression Results
# ...
# Dep. Variable:          grad_150_rate   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     4427.
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):               0.00
# Time:                        10:43:10   Log-Likelihood:            -7.8901e+05
# No. Observations:              163332   AIC:                         1.578e+06
# Df Residuals:                  163329   BIC:                         1.578e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %%
dummy_vars = pd.get_dummies(cleaned_filtered_new_df_copy[['gender', 'race']])

# %%
dummy_vars_copy = dummy_vars.copy()

# %%
dummy_vars_copy_dropped = dummy_vars_copy.drop(columns=['race_Ai'])

# %%
dummy_vars_copy_dropped.head()
# Out:
#     gender_F  gender_M  race_A  race_B  race_H  race_W
# 58     False      True   False   False   False    True
# 59      True     False   False   False   False    True
# 61     False      True   False    True   False   False
# 62      True     False   False    True   False   False
# 64     False      True   False   False    True   False

# %%
X= dummy_vars_copy_dropped
#X = sm.add_constant(dummy_vars_copy_dropped)
#X.head(10)
y=cleaned_filtered_new_df_copy['grad_100_rate']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#                             OLS Regression Results
# ...
# Dep. Variable:          grad_100_rate   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.044
# Method:                 Least Squares   F-statistic:                     1494.
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):               0.00
# Time:                        10:43:30   Log-Likelihood:            -7.8252e+05
# No. Observations:              163332   AIC:                         1.565e+06
# Df Residuals:                  163326   BIC:                         1.565e+06
# Df Model:                           5
# Covariance Type:            nonrobust
# ...

# %%
X= dummy_vars_copy_dropped
y=cleaned_filtered_new_df_copy['grad_150_rate']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#                             OLS Regression Results
# ...
# Dep. Variable:          grad_150_rate   R-squared:                       0.035
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     1200.
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):               0.00
# Time:                        10:43:31   Log-Likelihood:            -7.9037e+05
# No. Observations:              163332   AIC:                         1.581e+06
# Df Residuals:                  163326   BIC:                         1.581e+06
# Df Model:                           5
# Covariance Type:            nonrobust
# ...

# %%
dummy_vars.head()
# Out:
#     gender_F  gender_M  race_A  race_Ai  race_B  race_H  race_W
# 58     False      True   False    False   False   False    True
# 59      True     False   False    False   False   False    True
# 61     False      True   False    False    True   False   False
# 62      True     False   False    False    True   False   False
# 64     False      True   False    False   False    True   False

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# %%
contingency_table = pd.crosstab(cleaned_filtered_new_df_copy['gender'], cleaned_filtered_new_df_copy['race'])

# %%
chi2, p, dof, expected = chi2_contingency(contingency_table)

# %%
print("Chi-square statistic:", chi2)
print("p-value:", p)
print("Degrees of freedom:", dof)
print(contingency_table)
# Out:
# Chi-square statistic: 44.46948767771848
# p-value: 5.125206084199292e-09
# Degrees of freedom: 4
# race        A     Ai      B      H      W
# gender
# F       15730  11193  18321  17380  20501
# M       14911  10030  18067  16833  20366

# %%
contingency_table = pd.crosstab(cleaned_filtered_new_df_copy['control'], cleaned_filtered_new_df_copy['gender'])

# %%
chi2, p, dof, expected = chi2_contingency(contingency_table)

# %%
print("Chi-square statistic:", chi2)
print("p-value:", p)
print("Degrees of freedom:", dof)
# Out:
# Chi-square statistic: 48.5553496399987
# p-value: 2.8598271985962404e-11
# Degrees of freedom: 2

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=cleaned_filtered_new_df_copy, x='race', hue='gender')
plt.title('Distribution of Gender for Each Race')
plt.xlabel('Race')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.show()

# %%
cleaned_filtered_new_df_copy1 = cleaned_filtered_new_df_copy.copy()

# %%
dummy_vars = pd.get_dummies(cleaned_filtered_new_df_copy[['gender', 'race', 'control']])
dummy_vars_copy = dummy_vars.copy()
dummy_vars_copy_dropped = dummy_vars_copy.drop(columns=['gender_F', 'race_Ai'])

# %%
X= dummy_vars_copy_dropped
#X = sm.add_constant(dummy_vars_copy_dropped)
#X.head(10)
y=cleaned_filtered_new_df_copy['grad_100_rate']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#                             OLS Regression Results
# ...
# Dep. Variable:          grad_100_rate   R-squared:                       0.134
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     3606.
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):               0.00
# Time:                        10:43:45   Log-Likelihood:            -7.7444e+05
# No. Observations:              163332   AIC:                         1.549e+06
# Df Residuals:                  163324   BIC:                         1.549e+06
# Df Model:                           7
# Covariance Type:            nonrobust
# ...

# %%
print(X.dtypes)
# Out:
# gender_M                          bool
# race_A                            bool
# race_B                            bool
# race_H                            bool
# race_W                            bool
# control_private_for_profit        bool
# control_private_not_for_profit    bool
# control_public                    bool
# dtype: object

# %%
X = X.astype(int)
print(X.dtypes)
# Out:
# gender_M                          int64
# race_A                            int64
# race_B                            int64
# race_H                            int64
# race_W                            int64
# control_private_for_profit        int64
# control_private_not_for_profit    int64
# control_public                    int64
# dtype: object

# %%
dummy_vars = pd.get_dummies(cleaned_filtered_new_df_copy[['gender', 'race', 'control']], drop_first=True)
X = dummy_vars
X = X.astype(int)
X = sm.add_constant(X)
y = cleaned_filtered_new_df_copy['grad_100_rate']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#                             OLS Regression Results
# ...
# Dep. Variable:          grad_100_rate   R-squared:                       0.134
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     3606.
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):               0.00
# Time:                        10:43:54   Log-Likelihood:            -7.7444e+05
# No. Observations:              163332   AIC:                         1.549e+06
# Df Residuals:                  163324   BIC:                         1.549e+06
# Df Model:                           7
# Covariance Type:            nonrobust
# ...

# %%
dummy_vars = pd.get_dummies(cleaned_filtered_new_df_copy[['gender', 'race', 'control']], drop_first=True)
X = dummy_vars
X = X.astype(int)
X = sm.add_constant(X)
y = cleaned_filtered_new_df_copy['grad_150_rate']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#                             OLS Regression Results
# ...
# Dep. Variable:          grad_150_rate   R-squared:                       0.085
# Model:                            OLS   Adj. R-squared:                  0.085
# Method:                 Least Squares   F-statistic:                     2179.
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):               0.00
# Time:                        10:43:55   Log-Likelihood:            -7.8602e+05
# No. Observations:              163332   AIC:                         1.572e+06
# Df Residuals:                  163324   BIC:                         1.572e+06
# Df Model:                           7
# Covariance Type:            nonrobust
# ...

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
pd.read_excel('results.xlsx').to_csv('results.csv', index=False)

# %%
# Load the DataFrame from results.csv
df = pd.read_csv('results.csv')

# Assuming the DataFrame has columns 'gender' and 'grad_100_rate'
# If not, replace them with the correct column names

# Group the data by gender and calculate the mean graduation rate
gender_mean = df.groupby('gender')['grad_100_rate'].mean().reset_index()

# Create a bar chart
plt.bar(gender_mean['gender'], gender_mean['grad_100_rate'], color=['pink', 'blue']) # Assuming blue for male, pink for female
plt.xlabel('Gender')
plt.ylabel('4 Year Graduation Rate (%)')
plt.title('Average 4 Year Graduation Rate by Gender')
plt.show()

# %%
gender_mean = df.groupby('gender')['grad_150_rate'].mean().reset_index()

# Create a bar chart
plt.bar(gender_mean['gender'], gender_mean['grad_150_rate'], color=['pink', 'blue']) # Assuming blue for male, pink for female
plt.xlabel('Gender')
plt.ylabel('6 Year Graduation Rate (%)')
plt.title('Average 6 Year Graduation Rate by Gender')
plt.show()

# %%
# Group the data by race and calculate the mean graduation rate
race_mean = df.groupby('race')['grad_100_rate'].mean().reset_index()

# Define the colors for each race
colors = ['blue', 'orange', 'green', 'red', 'purple'] #Assuming blue=American Indian, Orange=Asian, Greem=Black, red=Hispanic, purple = White

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(race_mean['race'], race_mean['grad_100_rate'], color=colors)

plt.xlabel('Race')
plt.ylabel('Average 4 year Graduation Rate (%)')
plt.title('Average 4 Year Graduation Rate by Race')

plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

plt.show()

# %%
 #Group the data by race and calculate the mean graduation rate
race_mean = df.groupby('race')['grad_150_rate'].mean().reset_index()

# Define the colors for each race
colors = ['blue', 'orange', 'green', 'red', 'purple'] #Assuming blue=American Indian, Orange=Asian, Greem=Black, red=Hispanic, purple = White

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(race_mean['race'], race_mean['grad_150_rate'], color=colors)

plt.xlabel('Race')
plt.ylabel('Average 6 year Graduation Rate (%)')
plt.title('Average 6 Year Graduation Rate by Race')

plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

plt.show()

# %%
# Group the data by 'control' and calculate the mean graduation rate
control_mean = df.groupby('control')['grad_100_rate'].mean()

# Plotting the stacked bar chart
plt.figure(figsize=(10, 6))
control_mean.plot(kind='bar', stacked=True, color=['blue', 'orange', 'green'])

plt.xlabel('University Type')
plt.ylabel('Average 4 Year Graduation Rate (%)')
plt.title('Average 4 YearGraduation Rate by Control')

plt.xticks(rotation=0)  # Rotate x-axis labels if necessary

plt.legend(title='Control')

plt.show()

# %%
# Group the data by 'control' and calculate the mean graduation rate
control_mean = df.groupby('control')['grad_150_rate'].mean()

# Plotting the stacked bar chart
plt.figure(figsize=(10, 6))
control_mean.plot(kind='bar', stacked=True, color=['blue', 'orange', 'green'])

plt.xlabel('University Type')
plt.ylabel('Average 6 Year Graduation Rate (%)')
plt.title('Average 6 YearGraduation Rate by Control')

plt.xticks(rotation=0)  # Rotate x-axis labels if necessary

plt.legend(title='Control')

plt.show()
